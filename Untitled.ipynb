# %%
import pandas as pd
# matplotlib = this is data visualisation library
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('GL_sal_data_cleaned.csv')
df.head()
# Out:
#                                  Job Title                 Salary Estimate  \
# 0                           Data Scientist  ₹417K-₹1,000K (Glassdoor Est.)
# 1                           Data Scientist    ₹698K-₹960K (Glassdoor Est.)
# 2  Data Scientist - Technology Development    ₹350K-₹679K (Glassdoor Est.)
# 3           Senior / Data Science Engineer  ₹490K-₹1,094K (Glassdoor Est.)
# 4          Business Analyst - Data Science    ₹479K-₹700K (Glassdoor Est.)
#
#                                      Job Description  Rating  \
# 0  If you are a data junkie who would like to wra...     3.1
# 1  Relocation Assistance Offered Within Country\r...     4.2
# 2  Relocation Level: Domestic\r\n\r\nHiring Manag...     3.6
# 3  Gainsight™ is a venture-backed, fast-growing t...     4.2
# 4  With a startup spirit and 90,000+ curious and ...     3.8
#
#                Company Name   Location                   Size  Founded  \
# 0          BlueJeans\r\n3.1  Bangalore   201 to 500 Employees     2009
# ...

# %%
df.columns
